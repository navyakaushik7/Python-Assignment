# %% [markdown]
# <a href="https://colab.research.google.com/github/navyakaushik7/Python-Assignment/blob/main/ChallengeAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](data:application/octet-stream;base64,...)

# %%
L = ["Ram", 1, "Shyam", 2, "Aman", 3]
print("Original list:", L)

# Sort by converting all elements to strings for comparison
L.sort(key=lambda x: str(x))
print("Sorted list:", L)
